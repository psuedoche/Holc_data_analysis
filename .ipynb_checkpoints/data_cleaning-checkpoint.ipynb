# %%
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm
sns.set_theme()
sns.set_context('talk')

# %%
df1 = pd.read_csv('adform1.csv')
df2 = pd.read_csv('adform2.csv')
df3 = pd.read_csv('adform4.csv')

# %%
df1.head()
# Out:
#   polygon_id                                    desc_terrain  \
# 0        100  Level to rolling; overlooking Mill Creek park.
# 1       1000                         Level- flat and sloping
# 2       1001                                           Level
# 3       1003                                           Level
# 4       1005                                           Level
#
#                                     favor_influences  \
# 0  Very highly restricted. Fine winding streets. ...
# 1  Close to the schools, good bus transportation,...
# 2  Close to good bus transportation and community...
# 3  Close to transportation, theaters and business...
# 4  Near business area, parks, golf courses, recre...
#
#                                      detr_influences pct_improved  \
# 0  Generally free from all adverse influences exc...           60
# 1  Street improperly graded in places, waterways ...           20
# 2  Distances from schools. Absence of zoning rest...           40
# 3                          Encroachment of business.           80
# 4  Certain streets are zoned for and restricted t...           75
#
#    desirability                                         occupation  \
# 0  Static to up                       Bankers, and high executives
# 1      Up- slow           Business men, clerks & skilled mechanics
# 2          Down                       Clerks and skilled mechanics
# 3          Down              Merchants, laborers & winter tourists
# 4   Down slowly  Winter residents, executives, business and mis...
#
#     fam_income pct_foreign                   predom_eth  ...  \
# 0  10000-25000           0                          NaN  ...
# 1  1,000-4,000         NaN                         None  ...
# 2  1,800-3,000        None                         None  ...
# 3  2,000-6,000          50        German & Russian-jews  ...
# 4     3-25,000          30  Russian-German/ Polish Jews  ...
#
#   other2_rentdemandlim predom_build_rentact      other1_rentact  \
# 0                  NaN                 None                 NaN
# 1                  NaN                  NaN                 NaN
# 2                  NaN                 Fair                 NaN
# 3                  NaN   Good during season  Good during season
# 4                  NaN                    *                  **
#
#   other2_rentact  homebuy homebuild  \
# 0            NaN    Ample     Ample
# 1            NaN      NaN       NaN
# 2            NaN  Limited   Limited
# 3            NaN    Ample     Ample
# 4            NaN    Ample     Ample
#
#                                                notes  \
# 0  area consists of unusually fine and high class...
# 1  Approximately 150 houses in this area ranging ...
# 2  This area contains a heterogeneous mixture of ...
# 3  This is oldest area of Miami Beach and it is l...
# 4  *Rentals here are confined exclusively to the ...
#
#                                                 name sec_grade area_num
# 0                                 Cohassett District         A        4
# 1  Between Shorecrest & Miami Shores: Portion in ...         B        3
# 2  Both sides of N.E 6th Avenue & Biscayne Blvd. ...         C        3
# 3               Southern tip of Miami Beach, Florida         C       10
# 4        8th to Dade Boulevard, Miami Beach, Florida         B       11
#
# [5 rows x 93 columns]

# %%
df2.head()
# Out:
#   polygon_id rentdemand1  rentdemand2 rent_act      newconstr_type  \
# 0          1        none          NaN     none                none
# 1        130        Fair  Singles $35     None      Singles $3,000
# 2        131        Good  Singles $30     Poor  Singles & cottages
# 3        132        Good  Singles $30     Fair      Singles $3,500
# 4        133        good   single $40     none   singles at $4,800
#
#      newconstr_amt homebuy homebuild             desirability  \
# 0             none    Fair      Fair                      NaN
# 1         Mediocre   Ample     Ample         Slowly advancing
# 2  3-4 Parkman Rd.   Ample     Ample  Possible slight advance
# 3         Mediocre   Ample     Ample                 Downward
# 4          about 6   ample     ample                 downward
#
#                                                notes  ... data7__60  \
# 0  No activity toward promotion. Not more than 25...  ...       NaN
# 1  This area is on the so-called "west side" not ...  ...       NaN
# 2  Southeastern part of area older - poorly plann...  ...       NaN
# 3  East of York Street nearly all American inhabi...  ...       NaN
# 4  about 6 very expensive homes along Mahoning at...  ...       NaN
#
#   lowprice_predom  lowprice_pct             lowrent pct_landocc pct_homeocc  \
# 0             NaN           NaN  No rental property         10%        100%
# 1           3,500        52.80%             30 - 45          35         100
# 2            2700        77.20%             15 - 30          35         100
# 3            2500        75.70%             15 - 30          85         100
# 4            4000        66.70%             30 - 40          90         100
#
#   pct_homeown salesdemand1             salesdemand2           sales_act
# 0        100%         none                      NaN                none
# 1          80         Fair           Singles $4,500                Slow
# 2          60       Slight           Singles $3,500   10 - 15 this year
# 3          70         Good  Singles $3,000 - $4,500  About 30 this year
# 4          80         fair            single $5,000                none
#
# [5 rows x 63 columns]

# %%
df3.head()
# Out:
#   polygon_id                 name not_on_form pop_inc pop_dec pop_static  \
# 0       2367  Rochester, New York         NaN     NaN     NaN        Yes
# 1       2368  Rochester, New York         NaN     NaN     NaN        Yes
# 2       2369  Rochester, New York         NaN  Slowly     NaN        NaN
# 3       2370  Rochester, New York         NaN  Slowly     NaN        NaN
# 4       2371  Rochester, New York         NaN  Slowly     NaN        NaN
#
#                                            class_occ pct_foreign  \
# 0  Business executives with incomes of from $10,0...           0
# 1  White collar and daily workers having incomes ...         15
# 2            White-collar with incomes of $2000-5000           0
# 3  Eastman Kodak Workers with incomes $1800-3000....           5
# 4  White collar and daily workers having incomes ...           3
#
#   nationalities pct_black  ...   holc_sales inst_sales mortgagefunds no193  \
# 0           NaN         0  ...            0          0         Ample     9
# 1      Italians         0  ...            0         21       Limited     9
# 2           NaN         0  ...  1 at $5,000         69         Ample     9
# 3       Italian         0  ...  10 at $3390        138         Ample     9
# 4         Mixed         0  ...            0         14       Limited     9
#
#                                           taxper1000  \
# 0  $19.54 Greece, $41.73 Roch. No sales reported ...
# 1  19.54 Greece, $60.93 (405) No sales reported f...
# 2                                              41.73
# 3  19.54 Greece, $41.73 Roch. Effective Tax Rate ...
# 4  19.54 Greece, $41.73 Roch. Effective Tax Rates...
#
#                                         desc_terrain  \
# 0  A small area advantageously located on the lak...
# 1  This area of slightly rolling ground, though f...
# 2  Terrain rises from the river and is slightly r...
# 3  A more recent and exceptionally homogeneous de...
# 4  The area is not over 10% improved, still lacks...
#
#                            location sec_grade area_num     date
# 0   Shore Front, Greece & Rochester       1st      A-1  11/1/39
# 1   Charlotte, Greece and Rochester       3rd      C-1  11-1-39
# 2  Lake Ave. - Lakeville, Rochester       2nd      B-1  11/1/39
# 3                Greece & Rochester  High 3rd      C-5  11-1-39
# 4                Greece & Rochester   Low 3rd      C-4  11-1-39
#
# [5 rows x 71 columns]

# %%
df1.columns
# Out:
# Index(['polygon_id', 'desc_terrain', 'favor_influences', 'detr_influences',
#        'pct_improved', 'desirability', 'occupation', 'fam_income',
#        'pct_foreign', 'predom_eth', 'black', 'pct_black', 'infiltration',
#        'relief_fam', 'pop_inc', 'pop_dec', 'pop_static', 'predom_build_pct',
#        'other1_pct', 'other2_pct', 'predom_build_type', 'other1_type',
#        'other2_type', 'predom_build_constr', 'other1_constr', 'other2_constr',
#        'predom_build_age', 'other1_age', 'other2_age', 'predom_build_repair',
#        'other1_repair', 'other2_repair', 'predom_build_pctocc',
#        'other1_pctocc', 'other2_pctocc', 'predom_build_pctown',
#        'other1_pctown', 'other2_pctown', 'predom_build_constrpastyr',
#        'other1_constrpastyr', 'other2_constrpastyr', 'predom_build_1929price',
#        'other1_1929price', 'other2_1929price', 'price2', 'predom_build_price2',
#        'predom_build_price2pct', 'other1_price2', 'other1_price2pct',
#        'other2_price2', 'other2_price2pct', 'price3', 'predom_build_price3',
#        'predom_build_price3pct', 'other1_price3', 'other1_price3pct',
#        'other2_price3', 'other2_price3pct', 'predom_build_salesdemandlim',
#        'other1_demandlim', 'other2_demandlim', 'predom_build_salesact',
#        'other1_salesact', 'other2_salesact', 'predom_build_1929rent',
#        'other1_1929rent', 'other2_1929rent', 'rent2', 'predom_build_rent2',
#        'predom_build_rent2pct', 'other1_rent2', 'other1_rent2pct',
#        'other2_rent2', 'other2_rent2pct', 'rent3', 'predom_build_rent3',
#        'predom_build_rent3pct', 'other1_rent3', 'other1_rent3pct',
#        'other2_rent3', 'other2_rent3pct', 'predom_build_rentdemandlim',
#        'other1_rentdemandlim', 'other2_rentdemandlim', 'predom_build_rentact',
#        'other1_rentact', 'other2_rentact', 'homebuy', 'homebuild', 'notes',
#        'name', 'sec_grade', 'area_num'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['polygon_id', 'rentdemand1', 'rentdemand2', 'rent_act',
#        'newconstr_type', 'newconstr_amt', 'homebuy', 'homebuild',
#        'desirability', 'notes', 'source', 'date', 'no193', 'name', 'sec_grade',
#        'area_num', 'desc_terrain', 'favor_influences', 'detr_influences',
#        'inhab_type', 'fam_income', 'predom_eth', 'pct_predom_eth', 'black',
#        'pct_black', 'infiltration', 'relief_fam', 'pop_inc', 'pop_dec',
#        'data5_g_3', 'build_type', 'build_constr', 'build_age', 'build_repair',
#        'price1929', 'lowrent_predom', 'lowrent_pct', 'yr_current',
#        'currentprice', 'currentprice_predom', 'currentprice_pct',
#        'currentrent', 'currentrent_predom', 'currentrent_pct', 'peakprice',
#        'price1929_predom', 'peakprice_rel1929', 'peakrent', 'peakrent_rel1929',
#        'rent1929', 'rent1929_predom', 'yr_low', 'lowprice', 'data7__60',
#        'lowprice_predom', 'lowprice_pct', 'lowrent', 'pct_landocc',
#        'pct_homeocc', 'pct_homeown', 'salesdemand1', 'salesdemand2',
#        'sales_act'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['polygon_id', 'name', 'not_on_form', 'pop_inc', 'pop_dec', 'pop_static',
#        'class_occ', 'pct_foreign', 'nationalities', 'pct_black',
#        'infiltration', 'predom_build_pct', 'other1_pct', 'predom_build_type',
#        'other1_type', 'predom_build_constr', 'other1_constr',
#        'predom_build_age', 'other1_age', 'predom_build_repair',
#        'other1_repair', 'predom_build_occ', 'other1_occ',
#        'predom_build_ownocc', 'other1_ownocc', 'predom_build_1935price',
#        'other1_1935price', 'predom_build_1937price',
#        'predom_build_1937pctchange', 'other1_1937price',
#        'other1_1937pricepctchange', 'price3_yr', 'predom_build_price3',
#        'predom_build_price3pctchange', 'other1_price3',
#        'other1_price3pctchange', 'predom_build_demand', 'other1_demand',
#        'predom_build_pricetrend', 'other1_pricetrend', 'predom_build_1935rent',
#        'other1_1935rent', 'predom_build_1937rent',
#        'predom_build_1937rentpctchange', 'other1_1937rent',
#        'other1_1937rentpctchange', 'rent3', 'predom_build_rent3',
#        'predom_build_rent3pctchange', 'other1_rent3', 'other1_rent3pctchange',
#        'predom_build_rentdemand', 'other1_rentdemand',
#        'predom_build_renttrend', 'other1_renttrend', 'newconstr_amt',
#        'newconstr_type', 'newconstr_perform', 'holc_overhang', 'inst_overhang',
#        'sales_yr', 'holc_sales', 'inst_sales', 'mortgagefunds', 'no193',
#        'taxper1000', 'desc_terrain', 'location', 'sec_grade', 'area_num',
#        'date'],
#       dtype='object')

# %%
df1['desc_terrain'].unique()
# Out:
# array(['Level to rolling; overlooking Mill Creek park.',
#        'Level- flat and sloping', 'Level',
#        'Level filled in land; oldest island in group.',
#        'Level- This is all filled in land- properly and adequately bulkheaded.',
#        'Level, rolling toward Hill Creek Park.', 'Level,',
#        'Level, filled in land and bulkhead.', 'Flat',
#        'Level, filled in land; bulkheading completed around Isle.',
#        'Rolling.', 'level  and gently rolling', 'Rolling to hilly',
#        'Level and gently rolling.', 'Rolling', 'Level.',
#        'Level to rolling.', 'Level to rolling', 'Mostly rolling',
#        'Level to hilly', 'Level to rolling and hilly',
#        'Elevated and rolling', 'Elevated and rolling.',
#        'Hilly to rolling',
#        'Sloping upward from valley to crest of Red Mountain',
#        'Level to steeply sloping land.',
#        'Ranges from low damp to very hilly.',
#        'Level to rolling and mountainous',
#        'Rolling on side of Red Mountain',
#        'Ranges from roling and hilly in Hollywood and Mayfair to level in Edgewood.',
#        'Slightly rolling land in Shades Valley', 'Low to rolling',
#        'Rolling and hilly', 'Level to rolling ', 'Rolling and elevated',
#        'Rolling and elevated.', 'Level to rollling', 'Rolling to hilly.',
#        'Rolling - river valley.',
#        'Ranges from flat and level to rolling and elevated.',
#        'Level. Overlooks Maumee Bay.', 'Level. Sloping in places.',
#        'Slight slope to river.',
#        'Rolling to elevated with relatively small area level and flat. Eastern half of this area is inside city limits of Birmingham while the western half is in city limits of Fairfield. ',
#        'Sloping to river.', 'Level to slightly rolling', 'Low flat land.',
#        'Level land of medium elevation.',
#        'Land rises from low in the north.',
#        'Terrain is low and rises slightly to the south.',
#        'Land rises slightly from low ground in the north.',
#        'Low to level flat land', 'Low land rising to the south.',
#        'Low land.', 'Land is low, rising slightly to south.',
#        'Land is low, rising to south.', 'Low land, rising to the south.',
#        'Land is level.', 'Slightly elevated terrain.',
#        'Fairly high and level terrain.', 'Land rises to the south.',
#        'Land is level and fairly high.', 'Ground is high and rolling.',
#        'High and rolling terrain.',
#        'Fairly high ground, rising from the north.',
#        'Level and fairly high land.',
#        'Ground is high and rolling. Hillside.', 'High ground.',
#        'Ground is low, rising slightly to the south.',
#        'High and rolling land.', 'Terrain is high and rolling.',
#        'This section is comparatively low-lying; being situated in a valley.',
#        'Ground is rolling.', 'Slightly rolling terrain.',
#        'Land is generally flat except in eastern portion which rises slightly.',
#        'Low and flat land.', 'Land is low and flat.',
#        'Land rises gradually in the east.', 'Land is flat.',
#        'Mostly level', 'Hillside land.', 'High land sloping to the west.',
#        'Hillcrest and high.', 'Ground is high and flat.',
#        'Flat in west; steep hillside in northeast.',
#        'High and fairly flat land.',
#        'Rising ground which becomes flat in the east. ',
#        'Land rises steeply to the east.', 'Land is high and rolling.',
#        'Land is rolling and wooded.', 'Land slopes slightly to the west.',
#        'Land rises to northwest and southeast.',
#        'Land is low and rolling.',
#        'land rises steeply from the north and becomes high in the south.',
#        'Ground is low and flat.', 'Land rises slowly to the west.',
#        'Generally flat.', nan,
#        'Sloping upward from shore of Edgewoof Lake',
#        'Hilly and roling to undulating', 'Low and flat',
#        'Flat- gradual slope downward to Gravesend Bay.',
#        'Flat - gradual down slope westward',
#        'Flat, slight down slope west toward the harbor.',
#        'Slightly rolling',
#        'Slightly rolling with gradual down slope toward the Bay.',
#        'Slightly rolling with slope toward Bay.',
#        'Flat - gradual down slope westward.',
#        'Flat plateau - steep 40 foot drop at Furman St.',
#        'Slight downward slope toward the west.',
#        'Flat - gradual down grade to the south.',
#        'Flat but with gradual slope down toward the south.',
#        'Flat - gradual rise toward the southeast.',
#        'Steep hill down from Highland Blvd. to Sunnyside and Jamaica Aves. at foot',
#        'level', 'level - high elevation', 'level.', 'level to rolling',
#        'rolling', 'high elevation -level-',
#        'Description of Terrain. rolling to level; high elevation.',
#        'Fairly level.', 'Level to rolling; high elevation',
#        'level to slightly rolling', 'Level with decided slope to north',
#        'Side hill sloping from south to north, some steep grades.',
#        'Rolling with some steep grades.',
#        'Apex and slopes of a hill with many steep grades with frequent outcroppings of boulders, many of which are used in the landscaping. Southern portion is much less rugged.',
#        'Undulating crest of a high bluff, with many outcroppings of large boulders.',
#        'Level from east to west with some steep grades from south to north.',
#        'Fairly level from east to west with steep slopes and grades from south to north. Rugged and hilly with frequent outcroppings of boulders east of Crestling Avenue.',
#        'Series of rugged hills and vales, with outcroppings of boulders.',
#        'Somewhat rugged with many sharp grades. Generally sloping from south to north. Boulder outcroppings are numberous.',
#        'Fairly level with gentle undulations, somewhat rugged in southern part.',
#        'Top of a rise which slopes gently in every direction.',
#        'Generally level.',
#        'Level with slight slopes. Bluffs on northern and western boundaries',
#        'A level strip of bench land lying along the river underneath a steep bluff.',
#        'Latah Creek is a tributory of the Spokane River and runs through the area. Three bridges join the separate parts. The eastern and southern parts occupy the rugged slopes of a high hill, the crest of which is in the yellow hatched area to the West.',
#        '*', 'Generally level with no sharp grades.',
#        'Generally level with no steep grades.', 'Level with easy grades.',
#        'Level to rolling with no steep inclines.',
#        'Level with slight grades.',
#        'Level with gentle grades, somewhat rolling in western part.',
#        'Level with moderate grades.', 'Level with but few grades.',
#        'Two fairly level terraces with a sharp steep grade occupying the uncolored portion.',
#        'Level with but little grade.',
#        'Level plateau which ends in bluff on southern border.',
#        'Level, with but slight slopes from north to south.',
#        'Sloping from north to south fairly level from east to west.',
#        'Gently rolling with some fairly stiff grades in Northeast section.',
#        'Undulating to level with some grades in the northeast section.',
#        'Level with gentle grades. Largely covered with second growth pine.',
#        'Level with gentle slopes.',
#        'Generally level with slight undulations.',
#        'Level. No sharp grades.',
#        'Low level flat extending from the foot of a steep bluff, somewhat rugged in western part.',
#        'Level plateau extending northward from a high bluff with a slight slope from east to west.',
#        'Low, level with few grades.', 'Generally good.',
#        'Generally level with slight grades',
#        'Level with gravelly soil and very slight grades.', 'Flat.',
#        'Flat; rolling toward the lake.', 'Flat. Wooded.',
#        'Rolling. Wooded.',
#        'Sand dunes. Hills and hollows. It cost $2,000 to level some lots.',
#        'Flat. Shade trees-- planted trees 20-years old.',
#        'Flat. Shaded heavily.', 'Slightly rolling.', 'Fair.',
#        'Rolling. Shaded.', 'Flat. Shaded.', 'flat and wooded',
#        'Flat - Outside the City',
#        'Flat. Planted to trees, but no natural wood.', 'flat',
#        'Sloping and undulating with some 15 to 25% grades.',
#        'Level with slight undulation.',
#        'Side area sloping toward West without severe grades.',
#        'Hog back sloping east and west from Mason Street.',
#        'Generally level with slight undulation.',
#        'This area is identical with \'C-5\', except as noted in "Clarifying Remarks".',
#        'This area is similar in all respects to Areas \'C-7\' and \'C-8\' except as noted in "Clarifying Remarks".',
#        'Generally level, slightly rolling.',
#        'General level with slight slope to North East.',
#        'Slightly rolling with slope to West in extreme Western part.',
#        'Generally level - slightly rolling.',
#        'Level with very slight grade eastward.',
#        'Level with slight slope to North and East.',
#        'Practically level, with shallow gulch in Northeastern portion.',
#        'This area occupies the crests and slopes of a series of headlands which end in steep bluffs rising from the sound.',
#        'Hillside sloping toward north and east with some moderately steep grades.',
#        'Somewhat undulating, but without any steep grades.',
#        'Undulating but without any steep grades.',
#        'Undulating without steep grades.',
#        'Except as noted in "Clarifying Remarks" below, this area is identical in all respects with Area B-2\'.',
#        'This area occupies the crests and slopes of a series of headlands which end in steep bluffs rising from Puget Sound.',
#        'This area is identical in all respects, except as noted in "Clarifying Remarks", to area \'B-4\'.',
#        'Side of hill which slopes generally from West to East with varying grades.',
#        'Gentle slope to severe grade on South side.',
#        'Fairly level slope running from South to North',
#        'A low hill and adjacent level valley.', 'Level crest of a hill.',
#        'Level with slight undulations.', 'Low lying level.',
#        'Slightly undulating crest of a hill.',
#        'Level, sloping slightly to the North with undulations.',
#        'Level with slight slope to the North.',
#        'Level, somewhat undulating.',
#        'Fairly crest of a hill with sloping tendency toward East and South',
#        'Hog back Island running to sandy beach on Puget Sound and the Day Island waterway.',
#        'Level and slightly rolling tendency.',
#        'Sloping and undulating with some 15 to 25% grades',
#        'Level with slight grade.', 'level to hilly',
#        'hilly in southern part - level in north', 'hilly',
#        'level near railroad - rolling to hillside further back',
#        'hillside and hilltop', 'rolling and high',
#        'level - gradual upward slope to the southwest',
#        'Level below Charles St. Sloping up from Charles and Beacon St. near Common.',
#        'hillside',
#        'This area is similar in all respects to area "D-5" but is separated by the business section which is growing up between the two areas. South of Cambridge St. the neighborhood improves slightly as it abuts area "C-4". The general trend, however, is downward with business encroachment threatening to absorb the entire area north of Cambridge St. eventually.',
#        'slightly rolling', 'rolling slightly', 'rolling to level',
#        'level - hilly on Telegraph Hill', 'level - rolling in part',
#        'hillside to Cambridge St. - level to north',
#        'rolling, level and hilly', 'rolling to hilly',
#        'Hilly - on hilltop',
#        'This is a good apartment house area with rentals from $50 up. Overlooking the Charles River the neighborhood is one of the most desirable of its kind in the entire area.',
#        'Rolling - level near Mass. Ave.', 'Rolling - hilly',
#        'hilly - high',
#        'A small development of very small houses poorly constructed on poor ground. At present there are about 10 units in some stage of completion.',
#        'rolling - high', 'level - high',
#        'A few square blocks of mediocre houses adversely affected by proximity to to 4th grade section.',
#        'level - low ground', 'hilly - level on hilltop', 'Hilly',
#        'rolling toward center of city', 'rolling - level in spots',
#        'Generally flat terrain.', 'Fairly high and quite flat.',
#        'Slightly rolling ground.',
#        'Land rises steeply to the south and east.',
#        'Land rises steeply to the south where it becomes high and flat.',
#        'Terrain is high and slightly rolling.',
#        'Low in south and slightly high in the north.',
#        'Land is low in south and slightly higher in the north.',
#        'Land is slightly high and flat.',
#        'Fairly high ground which is somewhat rolling.',
#        'Fairly flat land.', 'Land is somewhat rolling and high.',
#        'High and slightly rolling terrain.',
#        'Land is low in west and higher in the east.',
#        'Land rises to southeast.', 'Land rises steeply to the southeast.',
#        'High and fairly flat.', 'Slightly rolling land.',
#        'Rolling ground.', 'Rolling land.', 'Land rises to the east.',
#        'Land slopes to the river.', 'Land slopes toward the river.',
#        'Land is generally flat.', 'Land rises slightly from the river.',
#        'Land rises from the river and becomes rolling.',
#        'Generally flat land.',
#        'Fairly high land which is slightly rolling.', 'Level to sloping.',
#        'Area occupied southern part of hill mentioned in A-14 and description of terrain is the same. ',
#        'Northern part of the undulating crest of long hill or hog back having an elevation of from 400 to 500 feet, sloping rather abruptly to north and east, and more gradually to the south and west. Generally wooded. ',
#        'Western slope of Palatino Hill. Steep grades from west to east with many benches or terraces. Elevation from 100 to 250 feet, 75 to 100-foot bluff to riverbank and eastern boundary.',
#        'Eastern slope of Palatine Hills, elevation from 200 to 300 feet with moderate to sharp grades.',
#        'Level with favorable grades.',
#        'Level to slightly rolling with favorable grades.',
#        'Level with favorable grades, western boundary occupies a bluff overlooking Willamette River.',
#        'The area occupies a long hill or "hog back" which rises some 100 feet above surrounding territory',
#        'Fairly level with gradual slope from east to west and a distinct rolling tendency in northern portion.',
#        'Generally level with rolling tendency in northern part.',
#        'Rolling with no unfavorable grades. Northern part occupies crest of an eminence which slopes rather sharply on western border and provides view locations.',
#        'Level with rolling tendency. No unfavorable grades.',
#        'Rolling hill side with many grades of varying degrees.',
#        'Same as A-11, but somewhat less rugged and with more moderate grades. Elevation 800 to 900 feet.',
#        'Rugged top of a hill with many steep grades, having an elevation of some 200 feet.',
#        'Very similar to A-8 although more restricted in extent and with more pronounced grades. It also has a slightly greater elevation.Convenience to city center. Harmonious development and population. A secluded and exclusive residential district of great natural charm, affording many view locations. Schools, churches, recreational areas, trading centers reasonably available for areas of this type. Utilities and conveniences available.',
#        'Portland Heights occupies that rugged crest or an oblong eminence extending approximately 1 1/2 miles in a northeast and southwest direction and having an elevation of from 500 to 600 feet.',
#        'Series of wooded hills and headland having an elevation of 500 feet or more. Characterized by steep grades and bluffs, which afford many view locations.',
#        'Level with moderate grades upward from northeast to southwest and with tendency toward ruggedness in southwest portion.',
#        'Rolling with grades sloping generally from north and west to the east.',
#        'Generally level from north to south with pronounced grades from west to east.',
#        'A side hill, fairly level from north to south but with some sharp grades with downward slope from west to east.',
#        'A level hillside terrace with moderate slope from west to east, elevation approximately 200 feet. The southern and eastern boundaries are characterized by steep grades.',
#        'An elevated bench extending around three sides of higher elevation forming a terrace which slopes radially, the grades in some places being quite steep. Elevation 400 to 600 feet.',
#        'An elevation of some 700 to 800 feet which is very rugged and contains many steep grades.',
#        'A high elevation of some 800 or 900 feet with road contours adn steep grades.',
#        'A headland having an elevation of some 900 feet which overlooks a broad expanse of territory lying to the northwest and south. This headland was originally heavily wooded and much virgin timber remains. The topography of the area is characterized by rolling swales and well-rounded hills.',
#        'A foot hill location occupying the lower reaches of the Westside Hills. The southern part slopes gently toward the northeast, while the northern part is more rugged and is characterized by steeper grades, which afford some view locations. The extreme northern portion borders a 50 to 100-foot bluff.',
#        'Generally level with favorable grades. Some moderate to steep grades in southern part. ',
#        'Level with favorable grades sloping from northwest to southeast.',
#        'Level to rolling with slightly hilly tendency in nrotheast section. No steep grades.',
#        'Western slope of an ominence of some 500 feet having its crest in Mt. Tabor Park. Grades while moderate provide many view locations.',
#        'Southwestern slope from mt. Tabor generally level with moderate grades from northeast to southwest.',
#        'Southern and southeast slope of Mt. Tabor. Topography similar to C-26.',
#        'Level with favorable grades running from east to west.',
#        'Level with tendency toward ruggedness in western part.',
#        'Northern shoulder of Mt. Tabor. None of the east and west streets are improved through the eastern part of this area owing to the steep grades encountered. The part of Mt. Tabor in area varies from 200 to 400 feet. The western part of the area occupies the northern and western slope of this eminence and is characterized by moderate to steep grades.',
#        'Northwestern slope of Joseph Wood Hill, an eminence of some 500 feet. Generally level with no sharp grades. ',
#        'Rolling with some moderate grades.',
#        'Level with favorable grades and a tendency to slope from north to south.',
#        'Generally level and tree-cover with favorable grades which increase noticeably in northern part.',
#        'Gradual slope southward from the brow of the Alameda at 57th Ave. and Sandy Blvd. The southern border extends along a gulch through which the Union Pacific Railroad enters the city.',
#        'Rolling with no sharp or unfavorable grades.',
#        'Level with favorable grades sloping from north to south.',
#        'Level with favorable grades from north to south.',
#        'Level with favorable grades. High bluff overlooking river on western boundary.',
#        'Level with slight grades. High bluff on southern and western boundary.',
#        'Level with gentle grades.',
#        'Level with favorable slopes for drainage.',
#        'Slightly rolling with gradual grade from south to north',
#        'Level with favorable grades. A high bluff extends along the southwest boundary of area above the O.W.R. & N. Co. tracts affording view locations. ',
#        'Level with favorable grades. Bluff on southern boundary.',
#        'Rolling with favorable grades. Low bluff on western boundary.',
#        'Level wooded area with favorable grades, sloping gently form south to north.',
#        'Level with favorable grades, sloping generally from north to south.',
#        'Level with favorable grades for drainage.',
#        'The top of a ridge with steep slopes from southern boundary and gentle slopes to north and east. Elevation 200 to 300 feet.',
#        'Generally level with favorable grades, a bluff in the northwest part affords some view locations.',
#        'Level with favorable grades with sharp slope on southern boundary.',
#        'A level wooded area with favorable grades.',
#        'Level with favorable grade.',
#        'Crest of a rugged ominence or headland with many steep grades which affords inspiring view locations. The slopes and much of the crest is heavily wooded. Elevation 800 to 1000 feet.',
#        'Level; section lying north of county line (north of Gypsy Lane) is slightly rolling',
#        'Level, excepting east end which is rolling to hilly.',
#        'Level - to slightly rolling.', 'Level, rolling.',
#        'Level to gently rolling.', 'Rolling, level.',
#        'Level to slightly rolling.',
#        'Level to slightly rising to the north.', 'Rolling to level.',
#        'Rolling to level; high elevation.', 'Flat land.',
#        'Low, flat terrain.', 'Land is low and swampy',
#        'Low and swampy land.', 'Flat and rather low terrain.',
#        'Flat land, low in spots.', 'Flat but slightly high ground.',
#        'Fairly high and flat.',
#        'High land rising steeply to the northwest.',
#        'Rolling land rising to west',
#        'Flat ground sufficiently high to escape danger of floods.',
#        'High and rolling ground.', 'Rising to the east.',
#        'Level to sloping toward Mill Creek to the south. Gradual rise from east to west.',
#        'Rolling and hilly.', 'Comparatively level.',
#        'Level to slightly up-grade from the north end to the south end.',
#        'Perfectly level.',
#        'Level. Slightly sloping toward Mill Creek Park.',
#        'Level to slightly sloping.',
#        'Level with no construction hazards. Low elevation indicates threat of flooded basements at times of high tides, because of hydrostatic pressure. This is ameliorated however, by a city pumping plant which is operated to overcome this hazard.',
#        'Level with no construction hazards. Low elevation indicares threat of flooded basements at times of high tides, because of hydrostatic pressure. Is ameliorated however, by a city pumping plant which is operated to overcome this hazard.',
#        'Level with no construction hazards. Low elevation indicates threat of flooded basements at times of high tides, because of hydrostatic pressure. This is ameliorated however, by a city pumping pllant which is operated to overcome this hazard.',
#        'Level with no construction hazards. Low elevation indicates threat of flooded basements at times of high tides, because of hydrosatic pressure. This is ameliorated however, by city pumping plant which is operated to overcome this hazard.',
#        'level to rolling.', 'Level with no construction hazards.',
#        'Rising to the south.',
#        'Level to slightly sloping from east to west', 'Level and flat',
#        'Level, but slightly elevated', 'high - hilly', 'Flat and level.',
#        'Level and rolling', 'Level and sloping',
#        'Level and well landscaped.', 'Rolling to Level'], dtype=object)
