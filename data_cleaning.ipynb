# %%
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm
sns.set_theme()
sns.set_context('talk')

# %%
df1 = pd.read_csv('adform1.csv')
df2 = pd.read_csv('adform2.csv')
df3 = pd.read_csv('adform4.csv')

# %%
df1.head()
# Out:
#   polygon_id                                    desc_terrain  \
# 0        100  Level to rolling; overlooking Mill Creek park.
# 1       1000                         Level- flat and sloping
# 2       1001                                           Level
# 3       1003                                           Level
# 4       1005                                           Level
#
#                                     favor_influences  \
# 0  Very highly restricted. Fine winding streets. ...
# 1  Close to the schools, good bus transportation,...
# 2  Close to good bus transportation and community...
# 3  Close to transportation, theaters and business...
# 4  Near business area, parks, golf courses, recre...
#
#                                      detr_influences pct_improved  \
# 0  Generally free from all adverse influences exc...           60
# 1  Street improperly graded in places, waterways ...           20
# 2  Distances from schools. Absence of zoning rest...           40
# 3                          Encroachment of business.           80
# 4  Certain streets are zoned for and restricted t...           75
#
#    desirability                                         occupation  \
# 0  Static to up                       Bankers, and high executives
# 1      Up- slow           Business men, clerks & skilled mechanics
# 2          Down                       Clerks and skilled mechanics
# 3          Down              Merchants, laborers & winter tourists
# 4   Down slowly  Winter residents, executives, business and mis...
#
#     fam_income pct_foreign                   predom_eth  ...  \
# 0  10000-25000           0                          NaN  ...
# 1  1,000-4,000         NaN                         None  ...
# 2  1,800-3,000        None                         None  ...
# 3  2,000-6,000          50        German & Russian-jews  ...
# 4     3-25,000          30  Russian-German/ Polish Jews  ...
#
#   other2_rentdemandlim predom_build_rentact      other1_rentact  \
# 0                  NaN                 None                 NaN
# 1                  NaN                  NaN                 NaN
# 2                  NaN                 Fair                 NaN
# 3                  NaN   Good during season  Good during season
# 4                  NaN                    *                  **
#
#   other2_rentact  homebuy homebuild  \
# 0            NaN    Ample     Ample
# 1            NaN      NaN       NaN
# 2            NaN  Limited   Limited
# 3            NaN    Ample     Ample
# 4            NaN    Ample     Ample
#
#                                                notes  \
# 0  area consists of unusually fine and high class...
# 1  Approximately 150 houses in this area ranging ...
# 2  This area contains a heterogeneous mixture of ...
# 3  This is oldest area of Miami Beach and it is l...
# 4  *Rentals here are confined exclusively to the ...
#
#                                                 name sec_grade area_num
# 0                                 Cohassett District         A        4
# 1  Between Shorecrest & Miami Shores: Portion in ...         B        3
# 2  Both sides of N.E 6th Avenue & Biscayne Blvd. ...         C        3
# 3               Southern tip of Miami Beach, Florida         C       10
# 4        8th to Dade Boulevard, Miami Beach, Florida         B       11
#
# [5 rows x 93 columns]

# %%
df2.head()
# Out:
#   polygon_id rentdemand1  rentdemand2 rent_act      newconstr_type  \
# 0          1        none          NaN     none                none
# 1        130        Fair  Singles $35     None      Singles $3,000
# 2        131        Good  Singles $30     Poor  Singles & cottages
# 3        132        Good  Singles $30     Fair      Singles $3,500
# 4        133        good   single $40     none   singles at $4,800
#
#      newconstr_amt homebuy homebuild             desirability  \
# 0             none    Fair      Fair                      NaN
# 1         Mediocre   Ample     Ample         Slowly advancing
# 2  3-4 Parkman Rd.   Ample     Ample  Possible slight advance
# 3         Mediocre   Ample     Ample                 Downward
# 4          about 6   ample     ample                 downward
#
#                                                notes  ... data7__60  \
# 0  No activity toward promotion. Not more than 25...  ...       NaN
# 1  This area is on the so-called "west side" not ...  ...       NaN
# 2  Southeastern part of area older - poorly plann...  ...       NaN
# 3  East of York Street nearly all American inhabi...  ...       NaN
# 4  about 6 very expensive homes along Mahoning at...  ...       NaN
#
#   lowprice_predom  lowprice_pct             lowrent pct_landocc pct_homeocc  \
# 0             NaN           NaN  No rental property         10%        100%
# 1           3,500        52.80%             30 - 45          35         100
# 2            2700        77.20%             15 - 30          35         100
# 3            2500        75.70%             15 - 30          85         100
# 4            4000        66.70%             30 - 40          90         100
#
#   pct_homeown salesdemand1             salesdemand2           sales_act
# 0        100%         none                      NaN                none
# 1          80         Fair           Singles $4,500                Slow
# 2          60       Slight           Singles $3,500   10 - 15 this year
# 3          70         Good  Singles $3,000 - $4,500  About 30 this year
# 4          80         fair            single $5,000                none
#
# [5 rows x 63 columns]

# %%
df3.head()
# Out:
#   polygon_id                 name not_on_form pop_inc pop_dec pop_static  \
# 0       2367  Rochester, New York         NaN     NaN     NaN        Yes
# 1       2368  Rochester, New York         NaN     NaN     NaN        Yes
# 2       2369  Rochester, New York         NaN  Slowly     NaN        NaN
# 3       2370  Rochester, New York         NaN  Slowly     NaN        NaN
# 4       2371  Rochester, New York         NaN  Slowly     NaN        NaN
#
#                                            class_occ pct_foreign  \
# 0  Business executives with incomes of from $10,0...           0
# 1  White collar and daily workers having incomes ...         15
# 2            White-collar with incomes of $2000-5000           0
# 3  Eastman Kodak Workers with incomes $1800-3000....           5
# 4  White collar and daily workers having incomes ...           3
#
#   nationalities pct_black  ...   holc_sales inst_sales mortgagefunds no193  \
# 0           NaN         0  ...            0          0         Ample     9
# 1      Italians         0  ...            0         21       Limited     9
# 2           NaN         0  ...  1 at $5,000         69         Ample     9
# 3       Italian         0  ...  10 at $3390        138         Ample     9
# 4         Mixed         0  ...            0         14       Limited     9
#
#                                           taxper1000  \
# 0  $19.54 Greece, $41.73 Roch. No sales reported ...
# 1  19.54 Greece, $60.93 (405) No sales reported f...
# 2                                              41.73
# 3  19.54 Greece, $41.73 Roch. Effective Tax Rate ...
# 4  19.54 Greece, $41.73 Roch. Effective Tax Rates...
#
#                                         desc_terrain  \
# 0  A small area advantageously located on the lak...
# 1  This area of slightly rolling ground, though f...
# 2  Terrain rises from the river and is slightly r...
# 3  A more recent and exceptionally homogeneous de...
# 4  The area is not over 10% improved, still lacks...
#
#                            location sec_grade area_num     date
# 0   Shore Front, Greece & Rochester       1st      A-1  11/1/39
# 1   Charlotte, Greece and Rochester       3rd      C-1  11-1-39
# 2  Lake Ave. - Lakeville, Rochester       2nd      B-1  11/1/39
# 3                Greece & Rochester  High 3rd      C-5  11-1-39
# 4                Greece & Rochester   Low 3rd      C-4  11-1-39
#
# [5 rows x 71 columns]

# %%
df1.columns
# Out:
# Index(['polygon_id', 'desc_terrain', 'favor_influences', 'detr_influences',
#        'pct_improved', 'desirability', 'occupation', 'fam_income',
#        'pct_foreign', 'predom_eth', 'black', 'pct_black', 'infiltration',
#        'relief_fam', 'pop_inc', 'pop_dec', 'pop_static', 'predom_build_pct',
#        'other1_pct', 'other2_pct', 'predom_build_type', 'other1_type',
#        'other2_type', 'predom_build_constr', 'other1_constr', 'other2_constr',
#        'predom_build_age', 'other1_age', 'other2_age', 'predom_build_repair',
#        'other1_repair', 'other2_repair', 'predom_build_pctocc',
#        'other1_pctocc', 'other2_pctocc', 'predom_build_pctown',
#        'other1_pctown', 'other2_pctown', 'predom_build_constrpastyr',
#        'other1_constrpastyr', 'other2_constrpastyr', 'predom_build_1929price',
#        'other1_1929price', 'other2_1929price', 'price2', 'predom_build_price2',
#        'predom_build_price2pct', 'other1_price2', 'other1_price2pct',
#        'other2_price2', 'other2_price2pct', 'price3', 'predom_build_price3',
#        'predom_build_price3pct', 'other1_price3', 'other1_price3pct',
#        'other2_price3', 'other2_price3pct', 'predom_build_salesdemandlim',
#        'other1_demandlim', 'other2_demandlim', 'predom_build_salesact',
#        'other1_salesact', 'other2_salesact', 'predom_build_1929rent',
#        'other1_1929rent', 'other2_1929rent', 'rent2', 'predom_build_rent2',
#        'predom_build_rent2pct', 'other1_rent2', 'other1_rent2pct',
#        'other2_rent2', 'other2_rent2pct', 'rent3', 'predom_build_rent3',
#        'predom_build_rent3pct', 'other1_rent3', 'other1_rent3pct',
#        'other2_rent3', 'other2_rent3pct', 'predom_build_rentdemandlim',
#        'other1_rentdemandlim', 'other2_rentdemandlim', 'predom_build_rentact',
#        'other1_rentact', 'other2_rentact', 'homebuy', 'homebuild', 'notes',
#        'name', 'sec_grade', 'area_num'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['polygon_id', 'rentdemand1', 'rentdemand2', 'rent_act',
#        'newconstr_type', 'newconstr_amt', 'homebuy', 'homebuild',
#        'desirability', 'notes', 'source', 'date', 'no193', 'name', 'sec_grade',
#        'area_num', 'desc_terrain', 'favor_influences', 'detr_influences',
#        'inhab_type', 'fam_income', 'predom_eth', 'pct_predom_eth', 'black',
#        'pct_black', 'infiltration', 'relief_fam', 'pop_inc', 'pop_dec',
#        'data5_g_3', 'build_type', 'build_constr', 'build_age', 'build_repair',
#        'price1929', 'lowrent_predom', 'lowrent_pct', 'yr_current',
#        'currentprice', 'currentprice_predom', 'currentprice_pct',
#        'currentrent', 'currentrent_predom', 'currentrent_pct', 'peakprice',
#        'price1929_predom', 'peakprice_rel1929', 'peakrent', 'peakrent_rel1929',
#        'rent1929', 'rent1929_predom', 'yr_low', 'lowprice', 'data7__60',
#        'lowprice_predom', 'lowprice_pct', 'lowrent', 'pct_landocc',
#        'pct_homeocc', 'pct_homeown', 'salesdemand1', 'salesdemand2',
#        'sales_act'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['polygon_id', 'name', 'not_on_form', 'pop_inc', 'pop_dec', 'pop_static',
#        'class_occ', 'pct_foreign', 'nationalities', 'pct_black',
#        'infiltration', 'predom_build_pct', 'other1_pct', 'predom_build_type',
#        'other1_type', 'predom_build_constr', 'other1_constr',
#        'predom_build_age', 'other1_age', 'predom_build_repair',
#        'other1_repair', 'predom_build_occ', 'other1_occ',
#        'predom_build_ownocc', 'other1_ownocc', 'predom_build_1935price',
#        'other1_1935price', 'predom_build_1937price',
#        'predom_build_1937pctchange', 'other1_1937price',
#        'other1_1937pricepctchange', 'price3_yr', 'predom_build_price3',
#        'predom_build_price3pctchange', 'other1_price3',
#        'other1_price3pctchange', 'predom_build_demand', 'other1_demand',
#        'predom_build_pricetrend', 'other1_pricetrend', 'predom_build_1935rent',
#        'other1_1935rent', 'predom_build_1937rent',
#        'predom_build_1937rentpctchange', 'other1_1937rent',
#        'other1_1937rentpctchange', 'rent3', 'predom_build_rent3',
#        'predom_build_rent3pctchange', 'other1_rent3', 'other1_rent3pctchange',
#        'predom_build_rentdemand', 'other1_rentdemand',
#        'predom_build_renttrend', 'other1_renttrend', 'newconstr_amt',
#        'newconstr_type', 'newconstr_perform', 'holc_overhang', 'inst_overhang',
#        'sales_yr', 'holc_sales', 'inst_sales', 'mortgagefunds', 'no193',
#        'taxper1000', 'desc_terrain', 'location', 'sec_grade', 'area_num',
#        'date'],
#       dtype='object')

# %%
df3['location'].unique()
# Out:
# array(['Shore Front, Greece & Rochester',
#        'Charlotte, Greece and Rochester',
#        'Lake Ave. - Lakeville, Rochester', 'Greece & Rochester',
#        'Kodak Section, Greece and Rochester', 'Rochester, N.Y.',
#        'Maplewood Park, Rochester', 'Rochester', 'Podunk Town Rochester',
#        'East Rochester Gates, Greece and Rochester',
#        'Chili Ave. - Genesee, Rochester',
#        '19th Ward - Sibley Tract, Arvine Heights - Genesec Park Blvd., Rochester',
#        'South West Central Section, Rochester', 'South Central Rochester',
#        'East Avenue Central, Rochester', 'Central Location, Rochester',
#        'Central Section, Rochester', 'St. Paul Driving Park, Rochester',
#        'Irondequoit and Rochester', 'North East Central Rochester',
#        'North East Central, Rochester', 'North Winton, Rochester',
#        'Irondequoit', 'Brownscroft, Rochester',
#        'Browncroft Extension, Brighton', 'East Avenue, Rochester',
#        'Werner Park, Rochester', 'Highland Parkway, Rochester',
#        'Highland Park Terrace, Rochester', 'Mt. Hope Cemetery, Rochester',
#        'University Heights Estate, Rochester', 'Brightondale, Rochester',
#        'Home Acres - Belle Aire - Struckman - Roselawn, Brighton',
#        'Meadow Brook, Brighton', 'Brooklea Gates',
#        'Latona Homesteads, Greece', 'Koda Vista, Greece',
#        'Inrondequoit & Rochester', 'Rogers Estates, Irondequoit',
#        'Winona Boulevard, Irondequoit',
#        'Boulevard Manor - Maywood, Irondequoit',
#        'Windsor Beach - Somerville, White City, Rock Beach. Irondequoit',
#        'Ellison Park Heights, Ferndale, Brighton', 'Brighton',
#        'East Avenue, Brighton & Rochester',
#        "Allen's Creek Road, Brighton", "Corbett's Glen, Brighton",
#        'Clover Hills, Brighton & Pittsford',
#        'Avondale-Huntington, Hills, Irondequoit & Rochester',
#        'Cottage Grove, Irondequoit', 'Cleveland (E. side)',
#        'Cleveland (E side)', 'Euclid',
#        'Euclid (Lake Shore Blvd. & South Blvd. Section)',
#        'Euclid (Utopia Beach #5)', 'Euclid (Utopia Beach #2 & #3)',
#        'Euclid (Beach Estates)',
#        'Cleveland (E side) (Euclid Beach Section)',
#        'Cleveland (E. side) (Waterloo - E. 152nd - Westropp - E. 140th)',
#        'Bratenahl', 'Cleveland (E. side) (Eddy Rd-Shaw Ave. Section)',
#        nan, 'Cleveland (E. side) (Lakeview - Chesterfield Section)',
#        'E. Cleveland (Euclid Ave. Section)',
#        'East Cleveland (Hayden Ave. Section)',
#        'Cleveland (E side) (Formerly Collinwood)',
#        'Euclid (Euclid Ave. - Dille Road - Chardon Road Section)',
#        'Euclid (Indian Hills)', 'Euclid (Euclid Villa)',
#        'Euclid (Sherwood-Forest Section)',
#        'Euclid (Beverly Hills Section)', 'Euclid, Chardon Hills Section',
#        'Cleveland (E. side), Colonial Hills',
#        'East Cleveland (Oakhill & Hanover)', 'Cleveland Heights',
#        'East Cleveland (Forest Hills)',
#        'Cleveland Hts. (Noble Rd. Section)', 'South Euclid',
#        'Cleveland Hts. (Severance Est.; Heaton-Pennington Subdiv.; Oak Ridge Subdiv.)',
#        'Cleveland (E. side) (Mayfield Rd., Italian Section)',
#        'Cleveland (E. side) (Wade Estates & Park Section)',
#        'Cleveland Heights (Mayfield Rd.-Euclid Hts. Blvd. Section',
#        'Cleveland Hts.', 'Cleveland Hts. (Fairmount Blvd. Section) ',
#        'University Hts.', 'University Heights',
#        'Lyndhurst (Park Estates)', 'Lyndhurst', 'Mayfield Hts. ',
#        'Shaker Heights (University Section)',
#        'Cleveland (E. side) (E. Blvd. - Woodland Section)',
#        'Cleveland (E. side) Cedar, Quincy, Woodland Section',
#        'Cleveland (E. side) (Shaker Square Section)',
#        'Shaker Heights (Huntington-Warrington Section)',
#        "Shaker Heights (100' front section & estates)",
#        'Shaker Heights (Fernway Section)',
#        'Shaker Heights (Lomond Section)',
#        'Cleveland (Shaker- Lee Subdiv.)', 'Shaker Hts. (S.W. Section)',
#        'Cleveland',
#        'Cleveland (E. side) (Kinsman - Mt. Pleasant Section)',
#        'Cleveland (E. side) (Buckeye Rd. Section)',
#        'Cleveland (E. side) (Kinsman - Woodhill Park Section)',
#        'Cleveland (E. sidio) (Corlett Section)',
#        'Cleveland (E. side) (E. 93rd - Union - Aetna Section)',
#        'Cleveland (E. Side) (formerly part of Miles Heights)',
#        'Cleveland (E. side) (Euclid - St. Clair Section from Pennsylvania R.R. to Wade Park)',
#        'Cleveland (E. side) (Miles Ave. District)',
#        'Garfield Hts. (Cranwood Section)',
#        'Garfield Hts. (Dressler Rd. Section)',
#        'Garfield Hts. (Orchard Ave. Section)',
#        'Cleveland (E. side) "Shantytown" (formerly part of Miles Heights)',
#        'Cleveland (E. side) (Formerly pary of Miles Hts.)', 'Maple Hts.',
#        'Maple Heights', 'Bedford', 'Bedford, Yorkshire Hts. ',
#        'Bedford Township', 'Bedford Twp. (Lincoln Heights)',
#        'Cleveland (E. side) (Harvard - Broadway - Warner Rd. Section)',
#        'Garfield Hts.', 'Garfield Heights',
#        'Maple Hts. (South of R.R. yards and Corkhill Section)',
#        'Maple Hts. (South of R.R. Yards & Corkhill Section)',
#        'Cleveland (E. side) (Aetna - Broadway - Fleet Section)',
#        'Newburh Hts.', 'Cleveland (W. side)', 'West Cleveland',
#        'Cleveland (E. side) (NE downtown)',
#        'Cleveland (E. side) (Woodland - 55th St. Section)',
#        'Cleveland (E. side) (Rawlings - Kinsman Section)', 'W. Cleveland',
#        'Lakewood', 'Cleveland (W.side)',
#        'Brook Park Twp. (Airport Section)', 'Rocky River',
#        'Fairview Village', 'Bay Village', 'Maplewood and Cahokia',
#        'Monsanto, E. St. Louis, Ill.', 'Alta Sita',
#        'E. St. Louis, I11. Alta Site', 'E. St. Louis, I11',
#        'E. St. Loui, 111.', 'East St. Louis', 'East St. Louis, Ill.',
#        'E. St. Louis, Ill.', 'M. L. Harris and Fairlawn Additions',
#        'Oak Park, Kingshighway Terrace, East St. Louis, Ill.',
#        'Olmsted Falls', 'Park Entrance Place', 'Simonin Place',
#        'Edgemont, E. St. Louis, Ill.', 'Outside E. St. Louis City Limits',
#        'Signal Hill', 'Glenview', 'Berea', 'Belleville, Illinois',
#        'Hill Top and Hill Top Annex', 'Prospect Park, Woodlawn Hills',
#        'Lansdowne', 'Pinehurst', 'Rosemont Manor, E. St. Louis, Ill.',
#        'Washington Park, E. St. Louis, Ill.',
#        'Fairmount City, E. St. Louis, Ill.',
#        'National City, Ill., E. St. Louis, Ill.',
#        'Brooklyn, E. St. Louis, Ill.',
#        'Venice, Illinois, E. St. Louis, Ill.', 'Venice',
#        'Madison, Ill., E. St. Louis, Ill.',
#        'Granite City, Ill., E. St. Louis, Mo.', 'Granite City',
#        'Nameoki, Ill., E. St. Louis, Ill.',
#        'Granite City, Ill., E. St. Louis, Ill.', 'Nameoki',
#        'Nameoki, Ill.', 'Bayonne ', 'Bayonne', 'Jersey City',
#        'North Bergen Twp.', 'Secaucus', 'Union City',
#        'Union City (the Dardanellos)', 'Weehawken, ', 'Weehawken',
#        'West New York ', 'West New York', 'Guttenberg',
#        'North Bergen Twp. ', 'North Bergen Twp. (Race track section)',
#        'Middleburgh Hts. (Whole community)', 'North bergen Twp',
#        'Hoboken', 'Kearney', 'Harrison', 'East Newark ', 'Parma Hts.',
#        'Kearney (Arlington)', 'Parma Heights', 'Parma',
#        'Parma (East of State Rd.)',
#        'Cleveland (W. side) (formerly Brooklyn)',
#        'Cleveland (W. side) (Formerly Brooklyn)',
#        "Brooklyn Hts. (Kleinman's & Pelham - Manor & Hollywood Subdivision)",
#        'Solon', 'Chagrin Falls', 'Fairmont Section, Camillus, N.Y.',
#        'Milton Ave, Sec, Solvay, N.Y.',
#        'Shady Lane Section, Gedess, N.Y.',
#        'Fay Road Section Geddes, N. Y',
#        'Shady Lane Section Solvay, N. Y.',
#        'Montrose Avenue Section Solvay, N.Y.',
#        'Barnet Park Section, Syracuse, N.Y.',
#        'Park Ave. Sec. Syracuse, N.Y.', 'West Onondaga Section, Suracuse',
#        'Belleview Section, Syracuse, N.Y.',
#        'Onondaga Park Section and Strathmore Section, Syracuse, N.Y.',
#        'Elmwood Section, Syracuse, N.Y.',
#        'South Side Section, Syracuse, N.Y.',
#        'Marcellus Street Section, Syracuse, N.Y.',
#        'Atlantic Avenue Section, Syracuse, N.Y.',
#        'Valley Section Syracuse, N. Y.',
#        'Seneca Turnpike Section Syracuse, N. Y.',
#        'Upper Nedrow Section Syracuse, N. Y.',
#        'Upper Section, Nedrew, N.Y.', 'Italian Section Syracuse, N.Y.',
#        'Lower Section, Nedrow, N.Y.',
#        'University Farm Section, Syracuse, N.Y.',
#        'Country Club Section Dewitt, N. Y.',
#        'Berkley & Bradford Hills Section, Syracuse, N.Y.',
#        'Syracuse, N.Y. University & Thorden Park Section',
#        'Gifford Manor Section Syracuse, N.Y.',
#        'Lowe Salt Springs Road Section Dewitt, N.Y',
#        'Maple Drive and Orvilton Park Section, Dewitt, N.Y.',
#        'Salt Springs Section, Syracuse, N.Y.',
#        'East Fayette Street Section, Syracuse, N.Y.',
#        'Negro Section, Syracuse, N.Y.',
#        'Townsend Street Section Syracuse, N.Y.',
#        'James Street Section Syracuse, N.Y.',
#        'Teal Avenue Section, Syracuse, N.Y.',
#        'Eastwood Section, Syracuse, N.Y.',
#        'Butternut Section, Syracuse, N.Y.',
#        'Lower court Street Section, Syracuse, N.Y.',
#        'Wolf Street Section, Suracuse, N.Y.',
#        'Upper Court Street section, Syracuse, N.Y.',
#        'Lyncourt Section Salina, N.Y',
#        'Upper Eastwood Section, Syracuse, N.Y.',
#        'Upper Court Street Section, Dwitt, N.Y.',
#        'Mattdydale, Galeville and Upper Court Street Section, Salina, N.Y.',
#        'East Syracuse, N.Y.', 'east Syracuse Section, Dewitt, N.Y.',
#        'Lodi Section, Syracuse, N.Y.',
#        'Tipperary Hill SEction, Syracuse, N.Y.',
#        'Charles Ave. Sec. Solvay, N.Y.',
#        'Westcott Reservoir Section, Syracuse, N.Y.',
#        'Mission Township Johnson County, Kansas',
#        'Mission Township Johnson County, Kan ', 'Kansas City, Kansas',
#        'Mission Township, Johnson County, Kan.',
#        'Mission Township Johnson County, Kan', 'Johnson County, Kan.',
#        'Mission Township Johnson County, Kan.', 'Overland Johnson County',
#        'Mission Township Johnson County',
#        'Mission Township Johnson County Kansas City, Kansas',
#        'Kansas City, MO', 'Mission Hills Johnson County, Kan.',
#        'Kansas City, MO.', 'Kansas City, MO. ',
#        'Jackson Co. Kansas City, MO. ', 'KANSAS CITY, MO. ',
#        'Wyandotte County, Kansas', 'Kansas city, Kansas',
#        'KANSAS CITY, MO.', 'Inter-City Jackson County, MO',
#        'Kansas City, Missouri', 'North Kansas City, MO',
#        'Jackson County, MO', 'Ashland Ridge Jackson County, Mo. ',
#        'Eastwood Hills,. Jackson County, MO',
#        'Raytown Jackson County, Mo. ', 'Jackson County, MO.',
#        'Kansas City, Mo. ', 'Jackson Co., Mo. ',
#        'Jackson CO., Kansas City, MO', 'Trenton', 'Riverview',
#        'Wyandotte', 'Wyandotto', 'Lincoln Park', 'Allen Park', 'Ecorse',
#        'River Rouge', 'Detroit, Mich.', 'Melvindale', 'Detroit, Mich. ',
#        'Dearborn', 'Detroit, Michigan', 'Clark Park', 'Detroit',
#        'Called Art Center', 'Detroit, Mich', 'Detroit, mich. ',
#        'Hamtramck', 'Detroit & southeastern tip of Highland Park',
#        'Highland Park', 'Detroit, Michigan ', 'Hazel Park', 'Brightmoor',
#        'Redford', 'Formerly Redford', 'Rosedale Park', 'Redford Township',
#        'Rodford Township', "Brady's Sub.", 'Farmington', 'Restmore Homes',
#        'As far south as Gladstone this is a part of Old Joy Farms',
#        'As far south as Gladstone & west of 12th was a part of Old Joy Farms',
#        'Known as Indian Village', 'Warren Township', 'Centerline',
#        'Ferndale', 'Palmer Woods & Sherwood Forest', 'Pleasant Ridge',
#        'Royal Oak', 'Royal Oak ', 'Huntington Woods', 'Berkley ',
#        'Royal Oal', 'Clawson', 'Birmingham', 'Southfield Township',
#        'Dearborn Township', 'Inkster', 'Dearborn ',
#        'Inkster [a]: Inkster', 'Garden City', 'Wayne', 'Sub-Wayne',
#        'Grosso Pointe Park', 'Grosse Pointe Park',
#        'City of Grosse Pointe', 'Grosso Pointe City',
#        'Grosse Pointe Farms', 'Grosso Pointe Farms', 'Grosse Pte. Farms',
#        'Grosse Pointe Shores', 'Lochmoor (Grosse Pointe Woods)',
#        'Lochmoor', 'St. Clair Shores', 'East Detroit', 'Roseville',
#        'Birmingham ', 'Newark Weegnahic Section',
#        'Newark Upper Weegnahic Section',
#        'Newark Shaw Ave. to D.L. & W.R.R. - Elizabeth Ave. to 20th St.',
#        '2nd', 'Newark; "Third Ward" etc.', 'Irvington',
#        'Irvington, Southern section adjoining Union County',
#        'Irvington Hardgrove Terrace', 'Irvington Chancellor Heights',
#        'Irvington East Central', 'Irvington Sanford Heights',
#        'Irvington Adjacent to Maplewood', 'Maplewood Hilton Districts',
#        'Newark Fairmount Cemetery- West Market St.',
#        'Newark North Roseville', 'Newark Roseville',
#        'East Orange- Grove St, East of Grove St., South of Ampere Station',
#        'East Orange', 'East Orange Ampere', 'Bloomfield',
#        'East Orange North Arlington Ave', 'East Orange Brick Church',
#        'East Orange Woodland Ave. - Brick Church', 'East Orange Central',
#        'East Orange North and Northwest Dodd Town, etc.',
#        'Orange; E. Orange', 'East orange Park Section (Watsessing)',
#        'Orange Central', 'Orange Cartaret Section',
#        'West Orange Valley Section', 'Orange Central Section',
#        'Montclair South East', 'Montclair South Side',
#        'Glen Ridge South Side', 'Glen Ridge', 'Glen Ridge North Side',
#        'Montclair North Side', 'Montclair Grove St. Mountain Hospital',
#        'Montclair', 'Montclair North Side Upper Montclair',
#        'Montclair Upper Montclair', 'Glen Ridge Ridgewood Ave., North',
#        'Glen Ridge Ridgewood Ave., South', 'Glen Ridge Central',
#        'Bloomfield North End', 'Nutley Alexander- Kenzel Ave.',
#        'Nutley Spring Garden Section', 'Nutley',
#        'Nutley Prospect St. Section', 'Nutley Yantacaw Park',
#        'Nutley Park', 'Nutley; Southwest', 'Belleville',
#        'Nutley; Southern', 'Nutley Mile Stretch- Nutley Park West',
#        'Nutley Centre. St.- Washington Blvd.', 'Belleville Hollywood',
#        'Belleville Graylock Section',
#        'Belleville Fairview Place- Luckewiac Place', 'Belleville Gardens',
#        'Belleville Belwood Park', 'Newark; Vailsburg',
#        'East Orange Clinton Sanford Sts.', 'East Orange Park End Section',
#        'Newark Vailsburg', 'South Orange', 'South Orange Tuxedo Park',
#        'South Orange Central', 'South Orange; Central',
#        'South Orange Southern Portion', 'Maplewood',
#        'Orange The Hills- Seven Oaks Park',
#        'South Orange Montrose Section',
#        'South Orange Mountainside-Newstead',
#        'Maplewood Summit Park, South Orange Heights, Blue Ridge Park',
#        'Millburn Wyoming Section- Model Park',
#        'Millburn Hillside- Sagamore Rd.',
#        'Maplewood Hillside- Roosevelt Park, etc.',
#        'Millburn South Mountain Estates', 'Millburn Center of Village',
#        'Millburn Short Hills, Brantwood, Green Acres, Beechcraft, Short Hills Estates, etc.',
#        'Millburn Glenwood, Oak Hills',
#        'West Orange Gregory Section- Hutton Park',
#        'West Orange St. Cloud', 'Verona', 'Verona Central',
#        'Verona Wayland', 'West Orange Eagle Rock Hillside',
#        'West Orange Llewellyn Park', 'West Orange Pleasantdale',
#        'West Orange Pleasant Valley Ave. & Mt. Pleasant Ave.',
#        'Newark; North Roseville', 'Belleville Silver Lake Section',
#        'Bloomfield Haleyon Place', 'Bloomfield Watsessing',
#        'Bloomfield Central', 'Bloomfield North Central',
#        'Bloomfield Ridge Section',
#        'Irvington Southern section adjoining Union County',
#        'North Newark Woodside Section', 'Newark Forest Hill Section',
#        'Newark; Ironbound Section', 'Nutley Terrace Avenue',
#        'Cedar Grove', 'Verona Verona Lake', 'Essex Fells',
#        'Caldwell- Boro', 'West Caldwell', 'Essex Falls Lower Section',
#        'Caldwell- Boro The Cedars', 'West Caldwell Oakland Heights',
#        'Livingston',
#        'North Caldwell-Caldwell Twp. West Caldwell- Roseland',
#        'Independence, Mo. ', 'Independence, MO',
#        'Inter-city Jackson Co., MO', 'Inter-City Jackson County, Mo. ',
#        'Allendale ', 'Allendalo ', 'Waldwick ',
#        'Waldwick "Ridgewald Highlands" ', '"Cheelcroft" Hohokus',
#        'Hohokus ', '"Knowllwood" Hohokus', 'Ridgewood ', 'Ridgewood',
#        'Ridgewood "Belmont Park"- "Woodmont Park"', 'Midland Park ',
#        'Ridgewood ("Beechmont Park")',
#        'Ridgewood "Carlyle Terrace" - "Woodside Park"', 'Glen Rock',
#        'Glen Rock ', 'Ridgewood "Manor Ridge"', 'Fairlawn',
#        'Fairlawn "Radburn"', 'East Paterson', 'Fairlawn "Warren Point"',
#        'East PPaterson', 'Garfield', 'Lodi', 'Hasbrouck Heights ',
#        'Hasbrouck Heights (Smoky Hollow)', 'Wallington ',
#        'East Rutherford', 'Moonachie', 'Woodridge', 'Carlstadt',
#        'Rutherford', 'Rutherford "Kip Farm Section" ', 'North Arlington',
#        'N. Arlington ', 'North Arlington ', 'Little Ferry', 'Hackensack ',
#        'Hackensack', 'Hackensack "Dublin Section" ',
#        'Hackensack "Garden Suburbs" ', 'Maywood', 'Maywood ',
#        'Rochelle Park ', 'Saddle River Township',
#        'Hackensack "Fairmont Section"', 'River Edge', 'Park Ridge',
#        'Montvale ', 'Hillsdale "Hillsdale Manor" ', 'Hillsdale',
#        'Hillsdale ', 'Washington Township', 'Westwood ', 'Westwood',
#        'Westwood "Hegeman Park" ', 'Emerson', 'Harrington Park ',
#        'Closter', 'Demarest', 'Haworth ', 'Dumont', 'Crosskill',
#        'Bergenfield', 'New Milford', 'River Edge ', 'Oradell', 'Oradell ',
#        'Tenafly (Central portion)', 'Tenafly (Eastern portion)',
#        'Tenafly West of R.R.', 'Englewood', 'Teaneck ',
#        'Teaneck "West Englewood" Section ',
#        'Teaneck (West Englewood Section)',
#        'Teaneck "West Englewood Section" ', 'Englewood Cliffs', 'Teaneck',
#        'Bogota', 'Ridgefield Park', 'Leonia', 'Palisades Park', 'Ft. Lee',
#        'Englewood Cliffs (Bayview Ave. Section)', 'Edgewater',
#        'Palisadew Park "Nannygoat Hill"', 'Ft. Lee (East Palisade)',
#        'Ft. Lee (Nanny Goat Hill) ', 'Ridgefield ', 'Cliffside Park',
#        'Cliffside Park (Greenmont Section) (West Grantwood)',
#        'Cliffside Park (Kearney Ave. Section) ',
#        'Cliffside Parl (East Grantwood)',
#        'Cliffside Park (Park Ave. Section) ',
#        'Cliffside Park (Walker St. Section) ', 'Fairview',
#        'Cliffside Park (Hudson Heights)',
#        'Cliffside Park (East Hudson Heights)', 'South Palos Verdes',
#        'Paseo Del Mar', 'San Pedro', 'WIlmington',
#        'Leminta (in L.A. County) Harbor City (L.A. City)', 'Torrance',
#        'Torrence', 'Alondro village', 'Gardena', 'Long Beach',
#        'Belmont Heights', 'Wrigley Tract', 'Bixby Heights',
#        'Wardlow Road and Long Beach Blvd. District', 'North Long Beach',
#        'Oak Knolls', 'Virginia Country Club - Long Beach',
#        'Santa Fe-Willow', 'Davidson City',
#        'Long Beach Blvd. and Market Street',
#        'Houghton Park and Atlantic Village', 'Huntington Park',
#        'Long Beach Blvd. and Artesia Street',
#        'Long Beach Blvd. at Artesia St.', 'Southeastern Compton',
#        'Compton', 'North Compton', 'Northwest Compton',
#        'Palos Verdes Estates and Hollywood Riviera', 'Redondo Beach',
#        'North Redondo Beach & Hermosa Beach', 'Manhattan Beach',
#        'Southwest Hawthorne', 'Southern Hawthorne and suburbs',
#        'Hawthorne', 'Inglewood', 'East Hawthorne', 'Southwest',
#        'Overhill', 'Windsor Hills', 'Hyde Park North', 'Morningisde Park',
#        'Gramercy Park', 'George Washington Heights', 'Angelus Mesa',
#        'View Park', 'Leimert Park', 'No name', 'South', 'Watts',
#        'Florence Industrial Dist.', 'Lynwood',
#        'Lynwood and small part of Southgate', 'Southgate', 'Walnut Park',
#        'Central Ave. Dist.', 'Jefferson and Arlington', 'Normandie-Adams',
#        'Berkeley Square District', 'Venice and Western',
#        '3rd & Washington', 'Victoria Park Dist.', 'West Adams',
#        'Venice-Burnside District', 'Pico and Fairfax Dist.',
#        'Carthay Circle Dist.', 'La Brea and Olympic', 'Willshire',
#        'Wilshire Dist.', 'Fremont Place', 'Windosr Square',
#        'Country Club Park', 'Washington-Vermont',
#        'Chester Place and St. James Park', 'Los Angeles',
#        'Westmoreland Place', 'Ambassador Hotel District', 'La Cienga',
#        'Robertson-Airdrome', 'La Ballona Creek', 'East Culver City',
#        'Robertson-Adams', 'Culver City', 'Culver City Park',
#        'Wilshire Country Club District',
#        'Windsor Square Wilshire District',
#        'West of Western bet. Wilshire to Beverly', 'Wilshire',
#        'Huntington Park, Maywood and Bell', 'Norwell Park City of Bell',
#        'Belvedere', 'Belvedere Gardens', 'Belvedere Gardons',
#        'Boyle Heights',
#        'Chadwick Drive - Templeton St. Dist. Los Angeles', 'Alhambra',
#        'Monterey Park', 'Northwest Alhambra', 'Monterey Hills',
#        'El Sereno-East Los Angeles', 'South Pasadena',
#        'Orange Grove Av. Pasadena', 'Pasadena Grand Avenue', 'Pasadena',
#        'Anandale Section, Pasadena', 'Herman', 'Eagle Rock', 'Highland',
#        'Glendale', 'Glendale Chevy Chase - Arcatia Dist.',
#        'Fletcher Drive and Verdugo Road Dist.', 'Mt. Washington',
#        'Verdugo Canyon', 'El Sereno Los Angeles',
#        'Huntington Villa Los Angeles', 'Lafayette Park', 'Bunker Hill',
#        'Elysian Park and Dog town District', 'East Hollywood',
#        'Elysian Park', 'Riverside Drive', 'Silver Lake Dist.',
#        'Los Feliz Hills', 'Laughlin Park', 'Hollywood', 'Ponet Terrace',
#        'Whitley Heights', 'Outpost Estates', 'Hollywood Blvd. Sec.',
#        'Hollywood District', 'Beverly-Fuller Dist.',
#        'Beverly to Melrose Gardner to Edinburgh',
#        'Hillside north of Sunset and west of Laurel Canyon',
#        'Fairfax-Willoughby Dist.', 'Fountain-Crescent Heights Dist.',
#        'Melrose-San Vicente District', 'Willshire-Fairfax',
#        'Rosewood - La Jolla District', 'Willshire-Fairfax District',
#        'Los Angeles County', 'West Hollywood', '3rd St. and Doheny Dr.',
#        'Beverly Hills', 'Clifton Way and Palm Drive',
#        'Colgate to Gregory Robertson to Arnez',
#        'Olympic Blvd. and Doheny Drive', 'Olympic Blvd. and Camden Drive',
#        'Olympic Blvd. and Carson Road', 'Sunset Blvd.',
#        'Bel-Air, Holmby Hills, Beverly Estates', 'Fox Hills',
#        'Overland - Pico', 'Monte Mar Vista', 'Sunset-Sepulveda',
#        'Brentwood Heights',
#        'Brentwood, Highland Hills and Tigertail Estates', 'Westgate',
#        'Brentwood Park', 'Sawtelle District', 'Willshire-Carmelina',
#        'Santa Monica North of Montana St.', 'Santa Monica',
#        'Santa Monica and Rustic Canyons', 'Riviera', 'Hunting Palisades',
#        'Pacific Palisades', 'West Pacific Palisades', 'Benedict Canyon',
#        'Beverly Glen', 'Mandeville Canyon', 'Los Angeles - Santa Monica',
#        'East Venice', 'Clover Field Add.', 'Barnes City', 'South Venice',
#        'Mesmer City', 'Mar Vista', 'Studio Village', 'West Palms',
#        'Westside Village', 'Palms Section', 'University City',
#        'Playa del Rey', 'El Segundo', 'San Fernando', 'Pacoima Park',
#        'Tujunga-Sunland District',
#        'Montrose, Sparr Hts. and La Crescenta',
#        'La Canada, North Chevy Chase, North Flintridge', 'Flintridge',
#        'Verdugo Woodlands', 'Verdugo Knolls', 'Chevy Chase', 'Rossmoyne',
#        'Olmstead-Highland District', 'Chevy Chase Dist. Verdugo Road',
#        'Highland (Glenoaks Dist.)',
#        'Glendale Pacific-Brand Glenoaks District',
#        'Chevy Chase-Broadway Dist. Glendale',
#        'Glendale - Pacific Ave. Colorado St. Dist.',
#        'Burbank and Glendale', 'Burbank', 'Lankershim',
#        'Lankershim Dist.', 'North Hollywood',
#        'North Hollywood, Toluca Lake and Hidden Village Dist.',
#        'Universal City', 'Southeast Van Nuys', 'Van Nuys',
#        'South Van Nuys', 'Encino', 'Hollywood Knolls',
#        'Linda Vista Pasadena', 'Montana and Lincoln Ave. District',
#        'N.W. Altadena', 'East side of Arroyo', 'Glenmore',
#        'East Glen Oaks', 'East Glendale', 'North Pasadena',
#        'N. E. Altadena', 'Lamanda Park', 'Lower Rancho Santa Anita',
#        'Santa Anita Oaks', 'Arcadia', 'Monrovia', 'East Arcadia',
#        'Arcadia (Baldwin-Stocker Estate)',
#        'Arcadia (Doreen Park and Santa Anita Vista Developments)',
#        'El Monte', 'Rosemead', 'Arcadia Rosemead', 'Temple City',
#        'Santa Anita Village', 'Michilinder Dist.',
#        'Chapman Woods (East Pasadena)', 'San Marino',
#        'Pasadena Cal-Tech Dist. ', 'Oak Knoll', 'Baldwin Park',
#        'Pasadena High School and Jr. College Dist.', 'Santa Anita',
#        'Sierra Madre', 'N. E. Pasaadena and Altadena', 'San Gabriel',
#        'Live Oak San Gabriel', 'Covina', 'Reseda', 'Canoga Park',
#        'San Dimas', 'La Verne', 'Laverne', 'Pomona',
#        'Pomona ( Ganesha Place)', 'Claremont',
#        'San Gabriel Village and So. San Gabriel',
#        'Monterey Park and Wilmar', 'ALhambra', 'Oak Knolls, San Marino',
#        'Altadena', 'No. Pasadena', 'Monterey Park Dist.',
#        'Montebello - West', 'Montebello', 'Montbello',
#        'San Gabirel Wash & Whittier Way', 'Pico', 'Whittier Suburb',
#        'Whittier', 'Eastridge', 'Rivera', 'Downey', 'Norwalk', 'Artesia',
#        'Lakewood Village', 'Bellflower Clearwater and Hynes',
#        'Sunset-Courtney East side of Laurel Canyon', 'Sunset Plaza',
#        'Santa Monica Chelsea-Arizona Dist.',
#        'Santa Monica Willshire- Washington to Montana',
#        'Belmont Shores and Naples', 'Hyde Park', 'Alamitos Heights',
#        'Airport Park', 'Hollywoodland', 'Upper Azusa', 'Azusa',
#        'South Azusa', 'Glendora', 'San Rafael Dist.', 'Beverly Crust',
#        'Elendale', 'Montebello Suburb',
#        'Cleveland (E. side) (Broadway-E.55th Section)', 'East Cleveland',
#        'Summit West Side', 'Borough of New Providence',
#        'New Providence Township (Berkley Heights)', 'Springfield',
#        'Union, Milltown', 'Westfield',
#        'Linden (Includes Tremley Section)', 'Clark Township',
#        'Kenilworth', 'Cranford', 'Westfield Castleman Ave. Section',
#        'Westfield Wychwood', '(South Side) Garwood',
#        'Centennial Ave. Cranford', 'Mountainside',
#        'Westfield; Germantown and Mountain Ave. section',
#        'Westfield; Tennis Club Section',
#        'Westfield; S. Euclid and S. Chestnut Section',
#        'Westfield Westfield Gardens and Indian Forrest',
#        'Westfield; Stonleigh Park', 'Westfield; Endree Crescent',
#        'Scotch Plains', 'Scotch Plains (Doorhurst)',
#        'Fanwood (North Side)', 'Fanwood (Center)', 'Fanwood (South side)',
#        'Scotch Plains (Maple Hill Farms)', 'Westfield Shackamaxon',
#        'Plainfield', 'North Plainfield (Somerset County)',
#        'Plainfield (Netherwood)',
#        'Sleepy Hollow and Evergreen Plainfield', 'Plainfield (Evergreen)',
#        'Plainfield (S.W.)', 'Rahway', 'Linden',
#        '(Sunnyfield Gardens) Linden', 'Roselle (Berlandt Park)',
#        'Roselle', 'West End Elizabeth', 'West and Elizabeth',
#        'Millburn; Hillside - Sagamore Rd.', 'Summit',
#        'Maplewood; Summit Park, South Orange Heights, Blue Ridge Park',
#        'Summit; Beechwood', 'Maplewood; Hillside - Roosevelt Park, etc.',
#        'Summit (East)',
#        'Millburn; Short Hills, Brantwood, Green Acres, Beechcraft, Short Hills Estates, etc.',
#        'Union, Vauxhall', 'Union North End', 'Union Center',
#        'Millburn; Glenwood, Oak Hills', 'Union Unionville&Arcadia Park',
#        'Union Floyd Tract', 'West Orange; St. Cloud', 'Union',
#        'West Orange; Gregory Section - Hutton Park', 'Hillside',
#        'Hillside (Weequahic Section)', 'Roselle park (Aldene)',
#        'Roselle Park', 'Union; Walton Park',
#        'Union Woodside Manor & Gruestelle Park', 'Elmora Hills Elizabeth',
#        'S. Elmora Elizabeth', 'Union Congress Park', 'Elmora Elizabeth',
#        'West Orange; Llewellyn Park', 'Cross Avenue Elizabeth',
#        'North End Elizabeth', 'Bay Way Elizabeth', 'South End Elizabeth',
#        'Elizabethport (West)', '(Central) Elizabethport',
#        'Elizabethport (East)', 'West Orange; Eagle Rock Hillside',
#        'N. Broad St. Elizabeth', 'Garwood (North Side)',
#        'Chattanooga, Tenn.'], dtype=object)
